# %% [markdown]
# # Tabular Classification with PyTorch & Optuna
#
# This notebook demonstrates advanced tabular classification using PyTorch, Optuna for hyperparameter tuning, and feature engineering.
#
# **Data Split Strategy:**
# - 80% of training data for model training and validation (cross-validation)
# - 20% of training data held out for final evaluation metrics
# - Final predictions made on test.csv

# %% [markdown]
# ## 1. Import Libraries and Set Seed
# Import all required libraries and set the random seed for reproducibility. Print the device being used (CPU/GPU).

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import os
import optuna
from optuna.samplers import TPESampler
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, classification_report, confusion_matrix

# Set seed for reproducibility
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
seed_everything(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Processing on: {DEVICE}")

BATCH_SIZE = 64
N_TRIALS = 500  # How many Optuna trials to run
# Out:
# ✅ Processing on: cpu

# %% [markdown]
# ## 2. Load Data and Feature Engineering
# Load train and test data, and apply advanced feature engineering.

# %%
def create_advanced_features(df):
    df = df.copy()
    activity_cols = ['hobby_engagement_level', 'physical_activity_index', 
                     'creative_expression_index', 'altruism_score']
    df['total_activity'] = df[activity_cols].sum(axis=1)
    df['support_guidance_combo'] = df['support_environment_score'] * (df['external_guidance_usage'] + 1)
    df['focus_efficiency'] = df['focus_intensity'] / (df['consistency_score'] + 1)
    df['consistency_gap'] = 30 - df['consistency_score']
    df['focus_sq'] = df['focus_intensity'] ** 2
    df['focus_X_consistency'] = df['focus_intensity'] * df['consistency_score']
    df['low_focus_high_consist'] = ((df['focus_intensity'] < 5) & (df['consistency_score'] > 24)).astype(int)
    return df

try:
    train_df = pd.read_csv('../dataset/train_20percent.csv')
    test_df = pd.read_csv('../dataset/test.csv')
except FileNotFoundError:
    raise FileNotFoundError("❌ Upload train_20percent.csv and test.csv!")

print(f"Total Training Data: {len(train_df)} samples")
print(f"Test Data: {len(test_df)} samples")

train_df = create_advanced_features(train_df)
test_df = create_advanced_features(test_df)

# Split training data into 80% train and 20% evaluation
X_full = train_df.drop(['participant_id', 'personality_cluster'], axis=1)
y_full = train_df['personality_cluster']

X_train, X_eval, y_train, y_eval = train_test_split(
    X_full, y_full, test_size=0.2, random_state=SEED, stratify=y_full
)

print(f"\n📊 Data Split:")
print(f"  Training Set (for model training & CV): {len(X_train)} samples (80%)")
print(f"  Evaluation Set (held out): {len(X_eval)} samples (20%)")
print(f"  Test Set (final predictions): {len(test_df)} samples")

test_ids = test_df['participant_id']
X_test = test_df.drop(['participant_id'], axis=1)
# Out:
# Total Training Data: 383 samples
# Test Data: 479 samples
#
# 📊 Data Split:
#   Training Set (for model training & CV): 306 samples (80%)
#   Evaluation Set (held out): 77 samples (20%)
#   Test Set (final predictions): 479 samples

# %% [markdown]
# ## 3. Preprocess Data (Encoding & Scaling)
# Encode categorical features and scale numerical features for train, eval, and test sets.

# %%
cat_cols = [
    'identity_code', 'cultural_background', 'age_group', 
    'upbringing_influence', 'support_environment_score', 
    'hobby_engagement_level', 'physical_activity_index',
    'creative_expression_index', 'altruism_score',
    'low_focus_high_consist'
]

cat_dims = []
for col in cat_cols:
    le = LabelEncoder()
    # Fit on all data to ensure consistency
    full_data = pd.concat([X_train[col], X_eval[col], X_test[col]], axis=0).astype(str)
    le.fit(full_data)
    X_train[col] = le.transform(X_train[col].astype(str))
    X_eval[col] = le.transform(X_eval[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))
    num_classes = len(le.classes_)
    emb_dim = min(50, (num_classes + 1) // 2)
    cat_dims.append((num_classes, emb_dim))

num_cols = [c for c in X_train.columns if c not in cat_cols]
scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_eval[num_cols] = scaler.transform(X_eval[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# Convert to numpy arrays
X_train_cat = X_train[cat_cols].values.astype(np.int64)
X_train_num = X_train[num_cols].values.astype(np.float32)
X_eval_cat = X_eval[cat_cols].values.astype(np.int64)
X_eval_num = X_eval[num_cols].values.astype(np.float32)
X_test_cat = X_test[cat_cols].values.astype(np.int64)
X_test_num = X_test[num_cols].values.astype(np.float32)

# %% [markdown]
# ## 4. Prepare Datasets and Class Weights
# Encode target labels, compute class weights, and prepare PyTorch datasets for training and validation.

# %%
target_le = LabelEncoder()
y_train_encoded = target_le.fit_transform(y_train)
y_eval_encoded = target_le.transform(y_eval)
num_classes_target = len(target_le.classes_)

print(f"Number of classes: {num_classes_target}")
print(f"Classes: {target_le.classes_}")

class_weights = compute_class_weight('balanced', classes=np.unique(y_train_encoded), y=y_train_encoded)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(DEVICE)
print(f"Class weights: {class_weights}")
# Out:
# Number of classes: 5
# Classes: ['Cluster_A' 'Cluster_B' 'Cluster_C' 'Cluster_D' 'Cluster_E']
# Class weights: [4.70769231 1.74857143 1.24897959 1.15471698 0.39230769]

# %% [markdown]
# ## 5. Define Dynamic Model Architecture
# Implement dataset and model classes for flexible tabular neural network modeling.

# %%
class AdvancedTabularDataset(Dataset):
    def __init__(self, x_cat, x_num, y=None):
        self.x_cat = torch.tensor(x_cat, dtype=torch.long)
        self.x_num = torch.tensor(x_num, dtype=torch.float)
        self.y = torch.tensor(y, dtype=torch.long) if y is not None else None
    def __len__(self): return len(self.x_cat)
    def __getitem__(self, idx):
        if self.y is not None: return self.x_cat[idx], self.x_num[idx], self.y[idx]
        return self.x_cat[idx], self.x_num[idx]

class DynamicTabularModel(nn.Module):
    def __init__(self, cat_dims, num_dim, output_dim, 
                 l1_size, l2_size, l3_size, 
                 emb_dropout, hidden_dropout):
        super(DynamicTabularModel, self).__init__()
        self.embeddings = nn.ModuleList([
            nn.Embedding(n, d) for n, d in cat_dims
        ])
        self.emb_dropout = nn.Dropout(emb_dropout)
        total_emb_dim = sum([d for _, d in cat_dims])
        input_dim = total_emb_dim + num_dim
        self.bn0 = nn.BatchNorm1d(num_dim)
        self.fc1 = nn.Linear(input_dim, l1_size)
        self.bn1 = nn.BatchNorm1d(l1_size)
        self.act1 = nn.GELU()
        self.drop1 = nn.Dropout(hidden_dropout)
        self.fc2 = nn.Linear(l1_size, l2_size)
        self.bn2 = nn.BatchNorm1d(l2_size)
        self.act2 = nn.GELU()
        self.drop2 = nn.Dropout(hidden_dropout)
        self.fc3 = nn.Linear(l2_size, l3_size)
        self.bn3 = nn.BatchNorm1d(l3_size)
        self.act3 = nn.GELU()
        self.drop3 = nn.Dropout(hidden_dropout / 2)
        self.output = nn.Linear(l3_size, output_dim)
    def forward(self, x_cat, x_num):
        emb_list = [emb(x_cat[:, i]) for i, emb in enumerate(self.embeddings)]
        x_emb = self.emb_dropout(torch.cat(emb_list, dim=1))
        x_num = self.bn0(x_num)
        x = torch.cat([x_emb, x_num], dim=1)
        x = self.drop1(self.act1(self.bn1(self.fc1(x))))
        x = self.drop2(self.act2(self.bn2(self.fc2(x))))
        x = self.drop3(self.act3(self.bn3(self.fc3(x))))
        return self.output(x)

# %% [markdown]
# ## 6. Optuna Hyperparameter Tuning
# Define the Optuna objective function and run the study to find the best hyperparameters using cross-validation on the 80% training set.

# %%
print(f"--- Starting Optuna Tuning ({N_TRIALS} Trials) ---")

def objective(trial):
    l1_size = trial.suggest_int('l1_size', 128, 512)
    l2_size = trial.suggest_int('l2_size', 64, 256)
    l3_size = trial.suggest_int('l3_size', 32, 128)
    emb_dropout = trial.suggest_float('emb_dropout', 0.1, 0.5)
    hidden_dropout = trial.suggest_float('hidden_dropout', 0.1, 0.5)
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    weight_decay = trial.suggest_float('weight_decay', 1e-6, 1e-3, log=True)
    
    # Use 3-fold CV on the 80% training set
    skf_tune = StratifiedKFold(n_splits=3, shuffle=True, random_state=SEED)
    scores = []
    
    for train_idx, val_idx in skf_tune.split(X_train_num, y_train_encoded):
        train_ds = AdvancedTabularDataset(X_train_cat[train_idx], X_train_num[train_idx], y_train_encoded[train_idx])
        val_ds = AdvancedTabularDataset(X_train_cat[val_idx], X_train_num[val_idx], y_train_encoded[val_idx])
        train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
        val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)
        
        model = DynamicTabularModel(cat_dims, X_train_num.shape[1], num_classes_target,
                                    l1_size, l2_size, l3_size, emb_dropout, hidden_dropout).to(DEVICE)
        criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
        
        for epoch in range(25):
            model.train()
            for c, n, y_batch in train_loader:
                c, n, y_batch = c.to(DEVICE), n.to(DEVICE), y_batch.to(DEVICE)
                optimizer.zero_grad()
                loss = criterion(model(c, n), y_batch)
                loss.backward()
                optimizer.step()
        
        model.eval()
        preds, labels = [], []
        with torch.no_grad():
            for c, n, y_batch in val_loader:
                c, n = c.to(DEVICE), n.to(DEVICE)
                p = torch.argmax(model(c, n), dim=1)
                preds.extend(p.cpu().numpy())
                labels.extend(y_batch.numpy())
        scores.append(f1_score(labels, preds, average='macro'))
        
        trial.report(scores[-1], 0)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
    
    return np.mean(scores)

sampler = TPESampler(seed=SEED)
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=N_TRIALS)

print("\n✅ BEST PARAMS FOUND:")
print(study.best_params)
best_p = study.best_params
# Out:
# [I 2025-12-02 22:19:33,987] A new study created in memory with name: no-name-2e88a9ce-1c25-48a0-a619-b78e85197a56
# --- Starting Optuna Tuning (500 Trials) ---
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:36,542] Trial 0 finished with value: 0.4223883740325754 and parameters: {'l1_size': 272, 'l2_size': 247, 'l3_size': 103, 'emb_dropout': 0.3394633936788146, 'hidden_dropout': 0.1624074561769746, 'lr': 0.00020511104188433984, 'weight_decay': 1.493656855461763e-06}. Best is trial 0 with value: 0.4223883740325754.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:37,822] Trial 1 finished with value: 0.4791580703858734 and parameters: {'l1_size': 461, 'l2_size': 180, 'l3_size': 100, 'emb_dropout': 0.10823379771832098, 'hidden_dropout': 0.4879639408647978, 'lr': 0.004622589001020831, 'weight_decay': 4.335281794951567e-06}. Best is trial 1 with value: 0.4791580703858734.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:38,846] Trial 2 finished with value: 0.41215589025954374 and parameters: {'l1_size': 198, 'l2_size': 99, 'l3_size': 61, 'emb_dropout': 0.3099025726528951, 'hidden_dropout': 0.2727780074568463, 'lr': 0.0003823475224675188, 'weight_decay': 6.847920095574779e-05}. Best is trial 1 with value: 0.4791580703858734.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:39,880] Trial 3 finished with value: 0.4145941877486028 and parameters: {'l1_size': 181, 'l2_size': 120, 'l3_size': 67, 'emb_dropout': 0.28242799368681437, 'hidden_dropout': 0.41407038455720546, 'lr': 0.00025081156860452336, 'weight_decay': 3.489018845491386e-05}. Best is trial 1 with value: 0.4791580703858734.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:40,914] Trial 4 finished with value: 0.5374810420664424 and parameters: {'l1_size': 356, 'l2_size': 72, 'l3_size': 90, 'emb_dropout': 0.16820964947491662, 'hidden_dropout': 0.12602063719411183, 'lr': 0.007902619549708232, 'weight_decay': 0.0007886714129990489}. Best is trial 4 with value: 0.5374810420664424.
# [I 2025-12-02 22:19:41,256] Trial 5 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:42,252] Trial 6 finished with value: 0.5168541874023819 and parameters: {'l1_size': 141, 'l2_size': 239, 'l3_size': 57, 'emb_dropout': 0.36500891374159283, 'hidden_dropout': 0.2246844304357644, 'lr': 0.001096821720752952, 'weight_decay': 4.366473592979636e-05}. Best is trial 4 with value: 0.5374810420664424.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:43,273] Trial 7 finished with value: 0.5138511913733658 and parameters: {'l1_size': 199, 'l2_size': 251, 'l3_size': 107, 'emb_dropout': 0.4757995766256756, 'hidden_dropout': 0.4579309401710595, 'lr': 0.0015696396388661157, 'weight_decay': 0.0005829384542994739}. Best is trial 4 with value: 0.5374810420664424.
# [I 2025-12-02 22:19:43,580] Trial 8 pruned.
# [I 2025-12-02 22:19:43,926] Trial 9 pruned.
# [I 2025-12-02 22:19:44,256] Trial 10 pruned.
# [I 2025-12-02 22:19:44,624] Trial 11 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:46,292] Trial 12 finished with value: 0.5108217434485386 and parameters: {'l1_size': 304, 'l2_size': 213, 'l3_size': 83, 'emb_dropout': 0.39193961757076157, 'hidden_dropout': 0.19080161642613747, 'lr': 0.0033598231172222806, 'weight_decay': 0.00013922931150160854}. Best is trial 4 with value: 0.5374810420664424.
# [I 2025-12-02 22:19:46,702] Trial 13 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:47,684] Trial 14 finished with value: 0.48779102523746604 and parameters: {'l1_size': 378, 'l2_size': 64, 'l3_size': 51, 'emb_dropout': 0.168021781822591, 'hidden_dropout': 0.347667150961637, 'lr': 0.0006797367925730756, 'weight_decay': 0.0002683717233779459}. Best is trial 4 with value: 0.5374810420664424.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:48,709] Trial 15 finished with value: 0.5076034258659913 and parameters: {'l1_size': 244, 'l2_size': 225, 'l3_size': 95, 'emb_dropout': 0.49178941408800114, 'hidden_dropout': 0.21338229453114393, 'lr': 0.002644487785633076, 'weight_decay': 1.2844377595711384e-06}. Best is trial 4 with value: 0.5374810420664424.
# [I 2025-12-02 22:19:49,046] Trial 16 pruned.
# [I 2025-12-02 22:19:49,365] Trial 17 pruned.
# [I 2025-12-02 22:19:49,721] Trial 18 pruned.
# [I 2025-12-02 22:19:50,030] Trial 19 pruned.
# [I 2025-12-02 22:19:50,364] Trial 20 pruned.
# [I 2025-12-02 22:19:50,697] Trial 21 pruned.
# [I 2025-12-02 22:19:51,038] Trial 22 pruned.
# [I 2025-12-02 22:19:51,381] Trial 23 pruned.
# [I 2025-12-02 22:19:51,706] Trial 24 pruned.
# [I 2025-12-02 22:19:52,032] Trial 25 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:53,251] Trial 26 finished with value: 0.5261194038520479 and parameters: {'l1_size': 163, 'l2_size': 205, 'l3_size': 106, 'emb_dropout': 0.47294753841894327, 'hidden_dropout': 0.1734365545172955, 'lr': 0.0037838634597870363, 'weight_decay': 8.348153002665915e-05}. Best is trial 4 with value: 0.5374810420664424.
# [I 2025-12-02 22:19:53,615] Trial 27 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:54,712] Trial 28 finished with value: 0.5287035921206916 and parameters: {'l1_size': 339, 'l2_size': 229, 'l3_size': 89, 'emb_dropout': 0.3074748988290139, 'hidden_dropout': 0.12656358664550738, 'lr': 0.003242952363980451, 'weight_decay': 3.00403234728096e-05}. Best is trial 4 with value: 0.5374810420664424.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:55,735] Trial 29 finished with value: 0.48167570695428513 and parameters: {'l1_size': 326, 'l2_size': 165, 'l3_size': 101, 'emb_dropout': 0.13804757297096645, 'hidden_dropout': 0.13163942251694657, 'lr': 0.003740065468448147, 'weight_decay': 2.092820305943043e-05}. Best is trial 4 with value: 0.5374810420664424.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:56,840] Trial 30 finished with value: 0.5094317489671165 and parameters: {'l1_size': 415, 'l2_size': 228, 'l3_size': 96, 'emb_dropout': 0.3012240763869659, 'hidden_dropout': 0.16141200432841582, 'lr': 0.007216445543581333, 'weight_decay': 6.313583912520275e-06}. Best is trial 4 with value: 0.5374810420664424.
# [I 2025-12-02 22:19:57,189] Trial 31 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:58,247] Trial 32 finished with value: 0.5126978882905363 and parameters: {'l1_size': 392, 'l2_size': 209, 'l3_size': 73, 'emb_dropout': 0.26431021143280586, 'hidden_dropout': 0.12379848988990026, 'lr': 0.004390190798174762, 'weight_decay': 9.4415833323914e-05}. Best is trial 4 with value: 0.5374810420664424.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:19:59,293] Trial 33 finished with value: 0.4989689916247905 and parameters: {'l1_size': 328, 'l2_size': 191, 'l3_size': 101, 'emb_dropout': 0.36068570923538157, 'hidden_dropout': 0.21112903715226064, 'lr': 0.002232284006909578, 'weight_decay': 2.231445915313895e-05}. Best is trial 4 with value: 0.5374810420664424.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:00,397] Trial 34 finished with value: 0.5427637000048057 and parameters: {'l1_size': 298, 'l2_size': 221, 'l3_size': 63, 'emb_dropout': 0.46276448833006284, 'hidden_dropout': 0.10209836247821817, 'lr': 0.0051711789011402425, 'weight_decay': 4.5399385493420046e-05}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:01,486] Trial 35 finished with value: 0.5214664241508321 and parameters: {'l1_size': 474, 'l2_size': 195, 'l3_size': 88, 'emb_dropout': 0.47086106346797607, 'hidden_dropout': 0.10128498217409146, 'lr': 0.005509439514805171, 'weight_decay': 2.1716244187383194e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:01,837] Trial 36 pruned.
# [I 2025-12-02 22:20:02,187] Trial 37 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:03,173] Trial 38 finished with value: 0.5210719089501424 and parameters: {'l1_size': 254, 'l2_size': 138, 'l3_size': 106, 'emb_dropout': 0.4758965965521691, 'hidden_dropout': 0.1789456252264362, 'lr': 0.004644201170670342, 'weight_decay': 2.1741836062482746e-06}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:03,513] Trial 39 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:04,525] Trial 40 finished with value: 0.5176811009352552 and parameters: {'l1_size': 341, 'l2_size': 182, 'l3_size': 89, 'emb_dropout': 0.46224605088479814, 'hidden_dropout': 0.279096083776436, 'lr': 0.005557737552909431, 'weight_decay': 8.809754463619421e-05}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:05,600] Trial 41 finished with value: 0.5381782502420666 and parameters: {'l1_size': 473, 'l2_size': 196, 'l3_size': 82, 'emb_dropout': 0.46770516362110975, 'hidden_dropout': 0.11619776194225505, 'lr': 0.005650764684774093, 'weight_decay': 2.502189871950321e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:06,173] Trial 42 pruned.
# [I 2025-12-02 22:20:06,552] Trial 43 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:07,701] Trial 44 finished with value: 0.5029042344616931 and parameters: {'l1_size': 441, 'l2_size': 232, 'l3_size': 66, 'emb_dropout': 0.49644006532916557, 'hidden_dropout': 0.11791288512877757, 'lr': 0.005295644934970158, 'weight_decay': 3.41411219871827e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:08,043] Trial 45 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:09,076] Trial 46 finished with value: 0.5389139654567924 and parameters: {'l1_size': 307, 'l2_size': 217, 'l3_size': 92, 'emb_dropout': 0.40776664685642783, 'hidden_dropout': 0.14314142265190458, 'lr': 0.00836510119673021, 'weight_decay': 1.6350671712635073e-05}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:10,121] Trial 47 finished with value: 0.5066946496978807 and parameters: {'l1_size': 306, 'l2_size': 219, 'l3_size': 92, 'emb_dropout': 0.4093078124576849, 'hidden_dropout': 0.10071414958251114, 'lr': 0.0087496197482132, 'weight_decay': 9.897406099857322e-06}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:10,425] Trial 48 pruned.
# [I 2025-12-02 22:20:10,777] Trial 49 pruned.
# [I 2025-12-02 22:20:11,119] Trial 50 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:12,341] Trial 51 finished with value: 0.49514431682628196 and parameters: {'l1_size': 355, 'l2_size': 207, 'l3_size': 77, 'emb_dropout': 0.4388324707653106, 'hidden_dropout': 0.1450885602329977, 'lr': 0.00422807001892535, 'weight_decay': 4.795778694437802e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:12,692] Trial 52 pruned.
# [I 2025-12-02 22:20:13,034] Trial 53 pruned.
# [I 2025-12-02 22:20:13,373] Trial 54 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:14,441] Trial 55 finished with value: 0.5026808192290363 and parameters: {'l1_size': 512, 'l2_size': 199, 'l3_size': 83, 'emb_dropout': 0.3767679257799672, 'hidden_dropout': 0.20056713853018726, 'lr': 0.0049062004658424465, 'weight_decay': 1.1888883768439783e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:14,785] Trial 56 pruned.
# [I 2025-12-02 22:20:15,158] Trial 57 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:16,155] Trial 58 finished with value: 0.5396002676626597 and parameters: {'l1_size': 215, 'l2_size': 219, 'l3_size': 110, 'emb_dropout': 0.34953339171745135, 'hidden_dropout': 0.13420914879016752, 'lr': 0.002675935633652817, 'weight_decay': 0.0003458853343572196}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:17,163] Trial 59 finished with value: 0.5168336281690724 and parameters: {'l1_size': 212, 'l2_size': 218, 'l3_size': 120, 'emb_dropout': 0.3545639038673214, 'hidden_dropout': 0.3707075467647747, 'lr': 0.0057550458567187605, 'weight_decay': 0.0003643180200984034}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:18,072] Trial 60 finished with value: 0.5327733157188993 and parameters: {'l1_size': 239, 'l2_size': 114, 'l3_size': 69, 'emb_dropout': 0.34797710247725355, 'hidden_dropout': 0.15368083645930644, 'lr': 0.0017401670488004389, 'weight_decay': 0.0007666292771253377}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:18,983] Trial 61 finished with value: 0.5077273693612555 and parameters: {'l1_size': 231, 'l2_size': 93, 'l3_size': 69, 'emb_dropout': 0.34172965767593055, 'hidden_dropout': 0.14990401933401384, 'lr': 0.0015045586519741205, 'weight_decay': 0.00020636323478794724}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:19,429] Trial 62 pruned.
# [I 2025-12-02 22:20:19,814] Trial 63 pruned.
# [I 2025-12-02 22:20:20,261] Trial 64 pruned.
# [I 2025-12-02 22:20:20,743] Trial 65 pruned.
# [I 2025-12-02 22:20:21,457] Trial 66 pruned.
# [I 2025-12-02 22:20:21,879] Trial 67 pruned.
# [I 2025-12-02 22:20:22,321] Trial 68 pruned.
# [I 2025-12-02 22:20:22,711] Trial 69 pruned.
# [I 2025-12-02 22:20:23,155] Trial 70 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:24,433] Trial 71 finished with value: 0.5323649606522977 and parameters: {'l1_size': 153, 'l2_size': 220, 'l3_size': 87, 'emb_dropout': 0.48206725323160937, 'hidden_dropout': 0.17397255390766497, 'lr': 0.005081329228210185, 'weight_decay': 1.7414148098962974e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:24,816] Trial 72 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:25,908] Trial 73 finished with value: 0.5017007920596902 and parameters: {'l1_size': 157, 'l2_size': 220, 'l3_size': 83, 'emb_dropout': 0.4837165017429697, 'hidden_dropout': 0.1669726518660244, 'lr': 0.004858694609455615, 'weight_decay': 1.6912819115146164e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:26,251] Trial 74 pruned.
# [I 2025-12-02 22:20:26,581] Trial 75 pruned.
# [I 2025-12-02 22:20:26,960] Trial 76 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:28,486] Trial 77 finished with value: 0.5175194568566662 and parameters: {'l1_size': 200, 'l2_size': 72, 'l3_size': 86, 'emb_dropout': 0.34499205507253944, 'hidden_dropout': 0.18754547756060766, 'lr': 0.006303821069826596, 'weight_decay': 1.7426026381131684e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:29,119] Trial 78 pruned.
# [I 2025-12-02 22:20:29,456] Trial 79 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:30,677] Trial 80 finished with value: 0.5038226196433085 and parameters: {'l1_size': 494, 'l2_size': 223, 'l3_size': 71, 'emb_dropout': 0.405688467211463, 'hidden_dropout': 0.17409380708074715, 'lr': 0.007152142664335451, 'weight_decay': 0.000813830907970401}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:31,038] Trial 81 pruned.
# [I 2025-12-02 22:20:31,423] Trial 82 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:32,334] Trial 83 finished with value: 0.504092124018313 and parameters: {'l1_size': 131, 'l2_size': 198, 'l3_size': 103, 'emb_dropout': 0.480427555467533, 'hidden_dropout': 0.16830567981525066, 'lr': 0.003060204784850427, 'weight_decay': 3.5812027245163294e-05}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:33,359] Trial 84 finished with value: 0.5313365000804405 and parameters: {'l1_size': 307, 'l2_size': 230, 'l3_size': 121, 'emb_dropout': 0.29042355621174426, 'hidden_dropout': 0.18366858256274998, 'lr': 0.005636184061796953, 'weight_decay': 0.00014099375275352448}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:33,710] Trial 85 pruned.
# [I 2025-12-02 22:20:34,026] Trial 86 pruned.
# [I 2025-12-02 22:20:34,385] Trial 87 pruned.
# [I 2025-12-02 22:20:34,735] Trial 88 pruned.
# [I 2025-12-02 22:20:35,062] Trial 89 pruned.
# [I 2025-12-02 22:20:35,406] Trial 90 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:36,429] Trial 91 finished with value: 0.5208441780107035 and parameters: {'l1_size': 373, 'l2_size': 206, 'l3_size': 110, 'emb_dropout': 0.432714482899162, 'hidden_dropout': 0.18247521197471378, 'lr': 0.004013741420731086, 'weight_decay': 8.8041787055209e-05}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:37,436] Trial 92 finished with value: 0.5312589447833367 and parameters: {'l1_size': 331, 'l2_size': 212, 'l3_size': 81, 'emb_dropout': 0.2726325790156981, 'hidden_dropout': 0.20322976735146278, 'lr': 0.005022549097748301, 'weight_decay': 5.780899945438928e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:37,780] Trial 93 pruned.
# [I 2025-12-02 22:20:38,121] Trial 94 pruned.
# [I 2025-12-02 22:20:38,472] Trial 95 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:39,670] Trial 96 finished with value: 0.49621480679160374 and parameters: {'l1_size': 325, 'l2_size': 211, 'l3_size': 80, 'emb_dropout': 0.28703212617402385, 'hidden_dropout': 0.1902285321708497, 'lr': 0.0034699966081085834, 'weight_decay': 0.00012760670964278895}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:40,022] Trial 97 pruned.
# [I 2025-12-02 22:20:40,417] Trial 98 pruned.
# [I 2025-12-02 22:20:40,755] Trial 99 pruned.
# [I 2025-12-02 22:20:41,104] Trial 100 pruned.
# [I 2025-12-02 22:20:41,438] Trial 101 pruned.
# [I 2025-12-02 22:20:41,765] Trial 102 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:42,734] Trial 103 finished with value: 0.5018678820743018 and parameters: {'l1_size': 209, 'l2_size': 227, 'l3_size': 96, 'emb_dropout': 0.4471978612479248, 'hidden_dropout': 0.23615398169270113, 'lr': 0.003926087366142121, 'weight_decay': 2.604581047765465e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:43,066] Trial 104 pruned.
# [I 2025-12-02 22:20:43,394] Trial 105 pruned.
# [I 2025-12-02 22:20:43,739] Trial 106 pruned.
# [I 2025-12-02 22:20:44,078] Trial 107 pruned.
# [I 2025-12-02 22:20:44,414] Trial 108 pruned.
# [I 2025-12-02 22:20:44,748] Trial 109 pruned.
# [I 2025-12-02 22:20:45,215] Trial 110 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:46,267] Trial 111 finished with value: 0.5176607215127292 and parameters: {'l1_size': 493, 'l2_size': 194, 'l3_size': 90, 'emb_dropout': 0.4718354562501063, 'hidden_dropout': 0.10582944918741315, 'lr': 0.008353960520644335, 'weight_decay': 2.2007193939506098e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:46,622] Trial 112 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:47,655] Trial 113 finished with value: 0.53748239350592 and parameters: {'l1_size': 447, 'l2_size': 200, 'l3_size': 86, 'emb_dropout': 0.417578822037328, 'hidden_dropout': 0.203665682911682, 'lr': 0.0054834313025338, 'weight_decay': 3.738177944849122e-05}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:47,993] Trial 114 pruned.
# [I 2025-12-02 22:20:48,337] Trial 115 pruned.
# [I 2025-12-02 22:20:48,735] Trial 116 pruned.
# [I 2025-12-02 22:20:49,093] Trial 117 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:50,142] Trial 118 finished with value: 0.5320246611942455 and parameters: {'l1_size': 482, 'l2_size': 209, 'l3_size': 97, 'emb_dropout': 0.3482472639642738, 'hidden_dropout': 0.20319174287596603, 'lr': 0.009352856962105582, 'weight_decay': 0.00041560794927561284}. Best is trial 34 with value: 0.5427637000048057.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:51,194] Trial 119 finished with value: 0.4892478267113134 and parameters: {'l1_size': 480, 'l2_size': 210, 'l3_size': 90, 'emb_dropout': 0.3525109341621303, 'hidden_dropout': 0.25662667281935947, 'lr': 0.008964980751036316, 'weight_decay': 0.00038959734478599515}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:51,563] Trial 120 pruned.
# [I 2025-12-02 22:20:51,915] Trial 121 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:53,365] Trial 122 finished with value: 0.5239206789381244 and parameters: {'l1_size': 460, 'l2_size': 220, 'l3_size': 85, 'emb_dropout': 0.3827678943976725, 'hidden_dropout': 0.2453340753743455, 'lr': 0.004917902153210715, 'weight_decay': 0.00044029287564908764}. Best is trial 34 with value: 0.5427637000048057.
# [I 2025-12-02 22:20:53,830] Trial 123 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:54,910] Trial 124 finished with value: 0.54404532865272 and parameters: {'l1_size': 384, 'l2_size': 190, 'l3_size': 89, 'emb_dropout': 0.3724280038856256, 'hidden_dropout': 0.1984083077514749, 'lr': 0.0034384039423212224, 'weight_decay': 5.641459816245006e-05}. Best is trial 124 with value: 0.54404532865272.
# [I 2025-12-02 22:20:55,275] Trial 125 pruned.
# [I 2025-12-02 22:20:55,638] Trial 126 pruned.
# [I 2025-12-02 22:20:56,068] Trial 127 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:57,125] Trial 128 finished with value: 0.5213526057481747 and parameters: {'l1_size': 360, 'l2_size': 225, 'l3_size': 78, 'emb_dropout': 0.3949025741953396, 'hidden_dropout': 0.15041548963962018, 'lr': 0.0026372730716125088, 'weight_decay': 4.17288478295693e-05}. Best is trial 124 with value: 0.54404532865272.
# [I 2025-12-02 22:20:57,484] Trial 129 pruned.
# [I 2025-12-02 22:20:57,858] Trial 130 pruned.
# [I 2025-12-02 22:20:58,183] Trial 131 pruned.
# [I 2025-12-02 22:20:58,533] Trial 132 pruned.
# [I 2025-12-02 22:20:58,912] Trial 133 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:20:59,858] Trial 134 finished with value: 0.5654360809099582 and parameters: {'l1_size': 151, 'l2_size': 204, 'l3_size': 93, 'emb_dropout': 0.34364460300893857, 'hidden_dropout': 0.14242178538631708, 'lr': 0.004705820212650299, 'weight_decay': 8.53319582166021e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:00,252] Trial 135 pruned.
# [I 2025-12-02 22:21:00,595] Trial 136 pruned.
# [I 2025-12-02 22:21:00,946] Trial 137 pruned.
# [I 2025-12-02 22:21:01,329] Trial 138 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:02,333] Trial 139 finished with value: 0.5214820295354757 and parameters: {'l1_size': 166, 'l2_size': 213, 'l3_size': 69, 'emb_dropout': 0.3301662845148019, 'hidden_dropout': 0.14740769988154964, 'lr': 0.005799683894727673, 'weight_decay': 0.0006235532276471951}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:02,727] Trial 140 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:03,672] Trial 141 finished with value: 0.5167116491652225 and parameters: {'l1_size': 144, 'l2_size': 191, 'l3_size': 94, 'emb_dropout': 0.45961570475431074, 'hidden_dropout': 0.20366363584132938, 'lr': 0.004218860006642826, 'weight_decay': 8.542704641331234e-05}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:04,669] Trial 142 finished with value: 0.5473715262903263 and parameters: {'l1_size': 183, 'l2_size': 198, 'l3_size': 99, 'emb_dropout': 0.42174927393485084, 'hidden_dropout': 0.2139554379344543, 'lr': 0.0037644629488835513, 'weight_decay': 8.251610315008223e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:05,012] Trial 143 pruned.
# [I 2025-12-02 22:21:05,353] Trial 144 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:06,267] Trial 145 finished with value: 0.5250365982772657 and parameters: {'l1_size': 235, 'l2_size': 85, 'l3_size': 88, 'emb_dropout': 0.4161809790862033, 'hidden_dropout': 0.2128634764239468, 'lr': 0.003122370482894, 'weight_decay': 0.00015766174193808534}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:07,219] Trial 146 finished with value: 0.5342837005244918 and parameters: {'l1_size': 129, 'l2_size': 201, 'l3_size': 99, 'emb_dropout': 0.39812047444895166, 'hidden_dropout': 0.113858323654617, 'lr': 0.0052428008696026925, 'weight_decay': 0.00028490053916029615}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:08,336] Trial 147 finished with value: 0.5243589926960713 and parameters: {'l1_size': 128, 'l2_size': 200, 'l3_size': 99, 'emb_dropout': 0.39642472025402353, 'hidden_dropout': 0.19286567144056752, 'lr': 0.0069733377355386955, 'weight_decay': 0.00028258086536113306}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:08,687] Trial 148 pruned.
# [I 2025-12-02 22:21:09,157] Trial 149 pruned.
# [I 2025-12-02 22:21:09,465] Trial 150 pruned.
# [I 2025-12-02 22:21:09,796] Trial 151 pruned.
# [I 2025-12-02 22:21:10,199] Trial 152 pruned.
# [I 2025-12-02 22:21:10,550] Trial 153 pruned.
# [I 2025-12-02 22:21:10,894] Trial 154 pruned.
# [I 2025-12-02 22:21:11,250] Trial 155 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:12,333] Trial 156 finished with value: 0.52549905955156 and parameters: {'l1_size': 185, 'l2_size': 233, 'l3_size': 93, 'emb_dropout': 0.3044990222851179, 'hidden_dropout': 0.15507657257651983, 'lr': 0.0048954153601809295, 'weight_decay': 0.0002717249959411806}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:12,680] Trial 157 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:13,757] Trial 158 finished with value: 0.5160564293439586 and parameters: {'l1_size': 345, 'l2_size': 191, 'l3_size': 85, 'emb_dropout': 0.33320905970985193, 'hidden_dropout': 0.16696836898443265, 'lr': 0.0017202910818123046, 'weight_decay': 2.3413865156282197e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:14,121] Trial 159 pruned.
# [I 2025-12-02 22:21:14,457] Trial 160 pruned.
# [I 2025-12-02 22:21:14,781] Trial 161 pruned.
# [I 2025-12-02 22:21:15,094] Trial 162 pruned.
# [I 2025-12-02 22:21:15,461] Trial 163 pruned.
# [I 2025-12-02 22:21:15,835] Trial 164 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:16,933] Trial 165 finished with value: 0.5138643561091379 and parameters: {'l1_size': 313, 'l2_size': 213, 'l3_size': 92, 'emb_dropout': 0.4000987133630005, 'hidden_dropout': 0.15055149912995514, 'lr': 0.006177647071308379, 'weight_decay': 1.999933329529181e-06}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:17,861] Trial 166 finished with value: 0.5318629861097737 and parameters: {'l1_size': 154, 'l2_size': 201, 'l3_size': 96, 'emb_dropout': 0.4327272771404136, 'hidden_dropout': 0.10691946713417091, 'lr': 0.005101482360706756, 'weight_decay': 5.923405086666965e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:18,261] Trial 167 pruned.
# [I 2025-12-02 22:21:18,583] Trial 168 pruned.
# [I 2025-12-02 22:21:18,887] Trial 169 pruned.
# [I 2025-12-02 22:21:19,262] Trial 170 pruned.
# [I 2025-12-02 22:21:19,593] Trial 171 pruned.
# [I 2025-12-02 22:21:19,936] Trial 172 pruned.
# [I 2025-12-02 22:21:20,326] Trial 173 pruned.
# [I 2025-12-02 22:21:20,676] Trial 174 pruned.
# [I 2025-12-02 22:21:21,199] Trial 175 pruned.
# [I 2025-12-02 22:21:21,587] Trial 176 pruned.
# [I 2025-12-02 22:21:21,941] Trial 177 pruned.
# [I 2025-12-02 22:21:22,284] Trial 178 pruned.
# [I 2025-12-02 22:21:22,668] Trial 179 pruned.
# [I 2025-12-02 22:21:23,124] Trial 180 pruned.
# [I 2025-12-02 22:21:23,981] Trial 181 pruned.
# [I 2025-12-02 22:21:24,343] Trial 182 pruned.
# [I 2025-12-02 22:21:24,757] Trial 183 pruned.
# [I 2025-12-02 22:21:25,129] Trial 184 pruned.
# [I 2025-12-02 22:21:25,460] Trial 185 pruned.
# [I 2025-12-02 22:21:25,801] Trial 186 pruned.
# [I 2025-12-02 22:21:26,115] Trial 187 pruned.
# [I 2025-12-02 22:21:26,479] Trial 188 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:27,550] Trial 189 finished with value: 0.5183480585059811 and parameters: {'l1_size': 178, 'l2_size': 226, 'l3_size': 82, 'emb_dropout': 0.4134617328121086, 'hidden_dropout': 0.15189312408254468, 'lr': 0.004164648974388891, 'weight_decay': 0.00020107885477603371}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:27,918] Trial 190 pruned.
# [I 2025-12-02 22:21:28,235] Trial 191 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:21:29,382] Trial 192 finished with value: 0.5095402442890659 and parameters: {'l1_size': 261, 'l2_size': 232, 'l3_size': 88, 'emb_dropout': 0.4206320200782372, 'hidden_dropout': 0.2107100799677929, 'lr': 0.0030061705596178155, 'weight_decay': 0.00015704597955783526}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:21:29,704] Trial 193 pruned.
# [I 2025-12-02 22:21:30,159] Trial 194 pruned.
# [I 2025-12-02 22:21:30,475] Trial 195 pruned.
# [I 2025-12-02 22:21:30,801] Trial 196 pruned.
# [I 2025-12-02 22:21:31,117] Trial 197 pruned.
# [I 2025-12-02 22:21:31,514] Trial 198 pruned.
# [I 2025-12-02 22:21:32,032] Trial 199 pruned.
# [I 2025-12-02 22:21:32,752] Trial 200 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# ...
# [I 2025-12-02 22:22:49,082] Trial 370 pruned.
# [I 2025-12-02 22:22:49,393] Trial 371 pruned.
# [I 2025-12-02 22:22:49,774] Trial 372 pruned.
# [I 2025-12-02 22:22:50,158] Trial 373 pruned.
# [I 2025-12-02 22:22:50,541] Trial 374 pruned.
# [I 2025-12-02 22:22:50,867] Trial 375 pruned.
# [I 2025-12-02 22:22:51,224] Trial 376 pruned.
# [I 2025-12-02 22:22:51,548] Trial 377 pruned.
# [I 2025-12-02 22:22:51,942] Trial 378 pruned.
# [I 2025-12-02 22:22:52,291] Trial 379 pruned.
# [I 2025-12-02 22:22:52,700] Trial 380 pruned.
# [I 2025-12-02 22:22:53,155] Trial 381 pruned.
# [I 2025-12-02 22:22:53,489] Trial 382 pruned.
# [I 2025-12-02 22:22:53,853] Trial 383 pruned.
# [I 2025-12-02 22:22:54,247] Trial 384 pruned.
# [I 2025-12-02 22:22:54,636] Trial 385 pruned.
# [I 2025-12-02 22:22:55,104] Trial 386 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:22:56,261] Trial 387 finished with value: 0.5114627898570722 and parameters: {'l1_size': 292, 'l2_size': 205, 'l3_size': 94, 'emb_dropout': 0.4671440749003263, 'hidden_dropout': 0.11698582741641733, 'lr': 0.004095980668646695, 'weight_decay': 0.0008283654301381568}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:22:57,546] Trial 388 finished with value: 0.5192481849321183 and parameters: {'l1_size': 384, 'l2_size': 216, 'l3_size': 98, 'emb_dropout': 0.36631488481236596, 'hidden_dropout': 0.13933556185018287, 'lr': 0.005263009419883715, 'weight_decay': 4.0774884711628664e-05}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:22:58,885] Trial 389 finished with value: 0.5603238385321875 and parameters: {'l1_size': 490, 'l2_size': 194, 'l3_size': 69, 'emb_dropout': 0.3361692134420505, 'hidden_dropout': 0.4447793195691431, 'lr': 0.004514099917100138, 'weight_decay': 6.792348610715444e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:22:59,282] Trial 390 pruned.
# [I 2025-12-02 22:22:59,695] Trial 391 pruned.
# [I 2025-12-02 22:23:00,154] Trial 392 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:01,374] Trial 393 finished with value: 0.5049075802345296 and parameters: {'l1_size': 404, 'l2_size': 197, 'l3_size': 65, 'emb_dropout': 0.33575637557653953, 'hidden_dropout': 0.43875170309854794, 'lr': 0.004279574552743604, 'weight_decay': 5.6563355891616525e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:01,684] Trial 394 pruned.
# [I 2025-12-02 22:23:02,058] Trial 395 pruned.
# [I 2025-12-02 22:23:02,428] Trial 396 pruned.
# [I 2025-12-02 22:23:02,836] Trial 397 pruned.
# [I 2025-12-02 22:23:03,224] Trial 398 pruned.
# [I 2025-12-02 22:23:03,591] Trial 399 pruned.
# [I 2025-12-02 22:23:03,959] Trial 400 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:04,942] Trial 401 finished with value: 0.4978139746169383 and parameters: {'l1_size': 134, 'l2_size': 223, 'l3_size': 88, 'emb_dropout': 0.4728189475510412, 'hidden_dropout': 0.4989240018784994, 'lr': 0.0050107575092847795, 'weight_decay': 6.208433148416933e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:05,292] Trial 402 pruned.
# [I 2025-12-02 22:23:05,654] Trial 403 pruned.
# [I 2025-12-02 22:23:06,000] Trial 404 pruned.
# [I 2025-12-02 22:23:06,347] Trial 405 pruned.
# [I 2025-12-02 22:23:06,771] Trial 406 pruned.
# [I 2025-12-02 22:23:07,173] Trial 407 pruned.
# [I 2025-12-02 22:23:07,510] Trial 408 pruned.
# [I 2025-12-02 22:23:07,906] Trial 409 pruned.
# [I 2025-12-02 22:23:08,232] Trial 410 pruned.
# [I 2025-12-02 22:23:08,657] Trial 411 pruned.
# [I 2025-12-02 22:23:09,125] Trial 412 pruned.
# [I 2025-12-02 22:23:09,545] Trial 413 pruned.
# [I 2025-12-02 22:23:09,894] Trial 414 pruned.
# [I 2025-12-02 22:23:10,291] Trial 415 pruned.
# [I 2025-12-02 22:23:10,637] Trial 416 pruned.
# [I 2025-12-02 22:23:11,024] Trial 417 pruned.
# [I 2025-12-02 22:23:11,354] Trial 418 pruned.
# [I 2025-12-02 22:23:11,732] Trial 419 pruned.
# [I 2025-12-02 22:23:12,076] Trial 420 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:13,085] Trial 421 finished with value: 0.5200811861493185 and parameters: {'l1_size': 311, 'l2_size': 104, 'l3_size': 90, 'emb_dropout': 0.3867039973937496, 'hidden_dropout': 0.462866027616091, 'lr': 0.00394069568777131, 'weight_decay': 0.0005004983292714464}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:13,451] Trial 422 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:14,520] Trial 423 finished with value: 0.5461533120227274 and parameters: {'l1_size': 175, 'l2_size': 212, 'l3_size': 86, 'emb_dropout': 0.48061295547214317, 'hidden_dropout': 0.11478507710654991, 'lr': 0.002884060219360566, 'weight_decay': 2.1345545093091527e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:14,899] Trial 424 pruned.
# [I 2025-12-02 22:23:15,250] Trial 425 pruned.
# [I 2025-12-02 22:23:15,613] Trial 426 pruned.
# [I 2025-12-02 22:23:15,983] Trial 427 pruned.
# [I 2025-12-02 22:23:16,394] Trial 428 pruned.
# [I 2025-12-02 22:23:16,839] Trial 429 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:18,431] Trial 430 finished with value: 0.53954603543919 and parameters: {'l1_size': 170, 'l2_size': 204, 'l3_size': 117, 'emb_dropout': 0.49314254400495006, 'hidden_dropout': 0.11559728613685809, 'lr': 0.0030885774972391118, 'weight_decay': 0.00034658658523374457}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:19,538] Trial 431 finished with value: 0.5372437935240238 and parameters: {'l1_size': 170, 'l2_size': 252, 'l3_size': 117, 'emb_dropout': 0.4947980348248875, 'hidden_dropout': 0.1126609314611428, 'lr': 0.0029721876630001073, 'weight_decay': 0.00034209001546500685}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:20,691] Trial 432 finished with value: 0.5354030590220858 and parameters: {'l1_size': 174, 'l2_size': 251, 'l3_size': 123, 'emb_dropout': 0.4994788694622084, 'hidden_dropout': 0.10951811918064643, 'lr': 0.0029568657693932986, 'weight_decay': 0.00037617584635324174}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:21,169] Trial 433 pruned.
# [I 2025-12-02 22:23:21,530] Trial 434 pruned.
# [I 2025-12-02 22:23:22,038] Trial 435 pruned.
# [I 2025-12-02 22:23:22,422] Trial 436 pruned.
# [I 2025-12-02 22:23:22,798] Trial 437 pruned.
# [I 2025-12-02 22:23:23,171] Trial 438 pruned.
# [I 2025-12-02 22:23:23,536] Trial 439 pruned.
# [I 2025-12-02 22:23:23,899] Trial 440 pruned.
# [I 2025-12-02 22:23:24,258] Trial 441 pruned.
# [I 2025-12-02 22:23:24,638] Trial 442 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:26,220] Trial 443 finished with value: 0.5344878659907711 and parameters: {'l1_size': 161, 'l2_size': 242, 'l3_size': 121, 'emb_dropout': 0.49145235391019326, 'hidden_dropout': 0.1070328867003152, 'lr': 0.0036009344865861287, 'weight_decay': 0.00041609125415319995}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:26,655] Trial 444 pruned.
# [I 2025-12-02 22:23:27,119] Trial 445 pruned.
# [I 2025-12-02 22:23:27,669] Trial 446 pruned.
# [I 2025-12-02 22:23:28,210] Trial 447 pruned.
# [I 2025-12-02 22:23:28,601] Trial 448 pruned.
# [I 2025-12-02 22:23:29,050] Trial 449 pruned.
# [I 2025-12-02 22:23:29,460] Trial 450 pruned.
# [I 2025-12-02 22:23:29,853] Trial 451 pruned.
# [I 2025-12-02 22:23:30,310] Trial 452 pruned.
# [I 2025-12-02 22:23:30,704] Trial 453 pruned.
# [I 2025-12-02 22:23:31,254] Trial 454 pruned.
# [I 2025-12-02 22:23:31,742] Trial 455 pruned.
# [I 2025-12-02 22:23:32,217] Trial 456 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:33,537] Trial 457 finished with value: 0.5179973427166413 and parameters: {'l1_size': 477, 'l2_size': 215, 'l3_size': 118, 'emb_dropout': 0.48596178030984216, 'hidden_dropout': 0.12133122844739, 'lr': 0.0038485244172135878, 'weight_decay': 0.0005724868543553978}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:34,002] Trial 458 pruned.
# [I 2025-12-02 22:23:34,382] Trial 459 pruned.
# [I 2025-12-02 22:23:34,820] Trial 460 pruned.
# [I 2025-12-02 22:23:35,310] Trial 461 pruned.
# [I 2025-12-02 22:23:35,731] Trial 462 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:36,989] Trial 463 finished with value: 0.5605048511822706 and parameters: {'l1_size': 185, 'l2_size': 229, 'l3_size': 127, 'emb_dropout': 0.4821275040319785, 'hidden_dropout': 0.10844612332136454, 'lr': 0.004723042384951243, 'weight_decay': 3.2143363309941587e-05}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:37,400] Trial 464 pruned.
# [I 2025-12-02 22:23:38,736] Trial 465 pruned.
# [I 2025-12-02 22:23:41,994] Trial 466 pruned.
# [I 2025-12-02 22:23:44,094] Trial 467 pruned.
# [I 2025-12-02 22:23:45,449] Trial 468 pruned.
# [I 2025-12-02 22:23:45,887] Trial 469 pruned.
# [I 2025-12-02 22:23:46,506] Trial 470 pruned.
# [I 2025-12-02 22:23:46,964] Trial 471 pruned.
# [I 2025-12-02 22:23:47,368] Trial 472 pruned.
# [I 2025-12-02 22:23:47,795] Trial 473 pruned.
# [I 2025-12-02 22:23:48,210] Trial 474 pruned.
# [I 2025-12-02 22:23:48,572] Trial 475 pruned.
# [I 2025-12-02 22:23:48,933] Trial 476 pruned.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:50,499] Trial 477 finished with value: 0.5561555231207448 and parameters: {'l1_size': 151, 'l2_size': 204, 'l3_size': 123, 'emb_dropout': 0.45916694747123765, 'hidden_dropout': 0.13580520619997302, 'lr': 0.0055592539273898855, 'weight_decay': 0.0004111567508321758}. Best is trial 134 with value: 0.5654360809099582.
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/optuna/trial/_trial.py:503: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-12-02 22:23:52,498] Trial 478 finished with value: 0.5521300597920796 and parameters: {'l1_size': 149, 'l2_size': 204, 'l3_size': 66, 'emb_dropout': 0.4563718109175928, 'hidden_dropout': 0.14048671351943515, 'lr': 0.00553172711427252, 'weight_decay': 0.00046410704410579156}. Best is trial 134 with value: 0.5654360809099582.
# [I 2025-12-02 22:23:54,186] Trial 479 pruned.
# [I 2025-12-02 22:23:54,889] Trial 480 pruned.
# [I 2025-12-02 22:23:56,134] Trial 481 pruned.
# [I 2025-12-02 22:23:57,375] Trial 482 pruned.
# [I 2025-12-02 22:23:58,020] Trial 483 pruned.
# [I 2025-12-02 22:23:58,874] Trial 484 pruned.
# [I 2025-12-02 22:23:59,417] Trial 485 pruned.
# [I 2025-12-02 22:24:00,095] Trial 486 pruned.
# [I 2025-12-02 22:24:01,446] Trial 487 pruned.
# [I 2025-12-02 22:24:02,259] Trial 488 pruned.
# [I 2025-12-02 22:24:02,925] Trial 489 pruned.
# [I 2025-12-02 22:24:03,610] Trial 490 pruned.
# [I 2025-12-02 22:24:04,333] Trial 491 pruned.
# [I 2025-12-02 22:24:04,915] Trial 492 pruned.
# [I 2025-12-02 22:24:05,362] Trial 493 pruned.
# [I 2025-12-02 22:24:05,903] Trial 494 pruned.
# [I 2025-12-02 22:24:06,437] Trial 495 pruned.
# [I 2025-12-02 22:24:06,962] Trial 496 pruned.
# [I 2025-12-02 22:24:07,400] Trial 497 pruned.
# [I 2025-12-02 22:24:07,931] Trial 498 pruned.
# [I 2025-12-02 22:24:08,385] Trial 499 pruned.
# ✅ BEST PARAMS FOUND:
# {'l1_size': 151, 'l2_size': 204, 'l3_size': 93, 'emb_dropout': 0.34364460300893857, 'hidden_dropout': 0.14242178538631708, 'lr': 0.004705820212650299, 'weight_decay': 8.53319582166021e-05}

# %% [markdown]
# ## 7. Final Model Training with Best Hyperparameters
# Retrain the model using the best hyperparameters found by Optuna on full 5-fold cross-validation using the 80% training set. Aggregate test predictions across folds.

# %%
print("\n--- Retraining Final Model with Best Params (5 Folds on 80% Training Data) ---")

skf_final = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
test_probs_sum = np.zeros((len(X_test), num_classes_target))
final_f1_scores = []
FINAL_EPOCHS = 50

for fold, (train_idx, val_idx) in enumerate(skf_final.split(X_train_num, y_train_encoded)):
    train_ds = AdvancedTabularDataset(X_train_cat[train_idx], X_train_num[train_idx], y_train_encoded[train_idx])
    val_ds = AdvancedTabularDataset(X_train_cat[val_idx], X_train_num[val_idx], y_train_encoded[val_idx])
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)
    
    model = DynamicTabularModel(
        cat_dims, X_train_num.shape[1], num_classes_target,
        best_p['l1_size'], best_p['l2_size'], best_p['l3_size'],
        best_p['emb_dropout'], best_p['hidden_dropout']
    ).to(DEVICE)
    
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=0.1)
    optimizer = optim.AdamW(model.parameters(), lr=best_p['lr'], weight_decay=best_p['weight_decay'])
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=best_p['lr']*10, 
                                              steps_per_epoch=len(train_loader), epochs=FINAL_EPOCHS)
    
    best_val_f1 = 0
    best_state = None
    
    for epoch in range(FINAL_EPOCHS):
        model.train()
        for c, n, y_batch in train_loader:
            c, n, y_batch = c.to(DEVICE), n.to(DEVICE), y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(c, n), y_batch)
            loss.backward()
            optimizer.step()
            scheduler.step()
        
        model.eval()
        preds, labels = [], []
        with torch.no_grad():
            for c, n, y_batch in val_loader:
                c, n = c.to(DEVICE), n.to(DEVICE)
                p = torch.argmax(model(c, n), dim=1)
                preds.extend(p.cpu().numpy())
                labels.extend(y_batch.numpy())
        
        f1 = f1_score(labels, preds, average='macro')
        if f1 > best_val_f1:
            best_val_f1 = f1
            best_state = model.state_dict()
    
    print(f"Fold {fold+1} | Best Validation F1: {best_val_f1:.4f}")
    final_f1_scores.append(best_val_f1)
    
    # Load best model state
    model.load_state_dict(best_state)
    model.eval()
    
    # Generate predictions on test set
    test_ds = AdvancedTabularDataset(X_test_cat, X_test_num)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)
    fold_probs = []
    with torch.no_grad():
        for c, n in test_loader:
            c, n = c.to(DEVICE), n.to(DEVICE)
            probs = torch.softmax(model(c, n), dim=1)
            fold_probs.append(probs.cpu().numpy())
    test_probs_sum += np.concatenate(fold_probs)

print(f"\n🏆 Average Cross-Validation F1 (on 80% training): {np.mean(final_f1_scores):.4f} ± {np.std(final_f1_scores):.4f}")
# Out:
# --- Retraining Final Model with Best Params (5 Folds on 80% Training Data) ---
# Fold 1 | Best Validation F1: 0.5911
# Fold 2 | Best Validation F1: 0.7183
# Fold 3 | Best Validation F1: 0.5231
# Fold 4 | Best Validation F1: 0.5539
# Fold 5 | Best Validation F1: 0.7447
#
# 🏆 Average Cross-Validation F1 (on 80% training): 0.6262 ± 0.0890

# %% [markdown]
# ## 8. Evaluate on Held-Out 20% Evaluation Set
# Evaluate the final model performance on the 20% held-out evaluation set to get unbiased metrics.

# %%
print("\n--- Evaluating on Held-Out 20% Evaluation Set ---")

# Train final model on entire 80% training set for evaluation
full_train_ds = AdvancedTabularDataset(X_train_cat, X_train_num, y_train_encoded)
full_train_loader = DataLoader(full_train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

eval_model = DynamicTabularModel(
    cat_dims, X_train_num.shape[1], num_classes_target,
    best_p['l1_size'], best_p['l2_size'], best_p['l3_size'],
    best_p['emb_dropout'], best_p['hidden_dropout']
).to(DEVICE)

criterion = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=0.1)
optimizer = optim.AdamW(eval_model.parameters(), lr=best_p['lr'], weight_decay=best_p['weight_decay'])
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=best_p['lr']*10, 
                                          steps_per_epoch=len(full_train_loader), epochs=FINAL_EPOCHS)

print(f"Training on full 80% training set for {FINAL_EPOCHS} epochs...")
for epoch in range(FINAL_EPOCHS):
    eval_model.train()
    for c, n, y_batch in full_train_loader:
        c, n, y_batch = c.to(DEVICE), n.to(DEVICE), y_batch.to(DEVICE)
        optimizer.zero_grad()
        loss = criterion(eval_model(c, n), y_batch)
        loss.backward()
        optimizer.step()
        scheduler.step()
    
    if (epoch + 1) % 10 == 0:
        print(f"  Epoch {epoch+1}/{FINAL_EPOCHS} completed")

# Evaluate on held-out 20%
eval_ds = AdvancedTabularDataset(X_eval_cat, X_eval_num, y_eval_encoded)
eval_loader = DataLoader(eval_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)

eval_model.eval()
eval_preds, eval_labels = [], []
with torch.no_grad():
    for c, n, y_batch in eval_loader:
        c, n = c.to(DEVICE), n.to(DEVICE)
        p = torch.argmax(eval_model(c, n), dim=1)
        eval_preds.extend(p.cpu().numpy())
        eval_labels.extend(y_batch.numpy())

eval_f1 = f1_score(eval_labels, eval_preds, average='macro')
print(f"\n📊 EVALUATION METRICS (20% Held-Out Set):")
print(f"Macro F1 Score: {eval_f1:.4f}")
print("\nClassification Report:")
print(classification_report(eval_labels, eval_preds, target_names=target_le.classes_))
print("\nConfusion Matrix:")
print(confusion_matrix(eval_labels, eval_preds))
# Out:
# --- Evaluating on Held-Out 20% Evaluation Set ---
# Training on full 80% training set for 50 epochs...
#   Epoch 10/50 completed
#   Epoch 20/50 completed
#   Epoch 30/50 completed
#   Epoch 40/50 completed
#   Epoch 50/50 completed
#
# 📊 EVALUATION METRICS (20% Held-Out Set):
# Macro F1 Score: 0.4542
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Cluster_A       0.00      0.00      0.00         4
#    Cluster_B       0.38      0.33      0.35         9
#    Cluster_C       0.35      0.58      0.44        12
#    Cluster_D       0.75      0.46      0.57        13
#    Cluster_E       0.92      0.90      0.91        39
#
#     accuracy                           0.66        77
#    macro avg       0.48      0.46      0.45        77
# weighted avg       0.69      0.66      0.67        77
#
#
# Confusion Matrix:
# [[ 0  2  1  0  1]
#  [ 3  3  3  0  0]
#  [ 0  3  7  2  0]
#  [ 0  0  5  6  2]
#  [ 0  0  4  0 35]]

# %% [markdown]
# ## 9. Save Predictions and Submission Files
# Save the test set prediction probabilities and final submission file as CSVs.

# %%
# Average test predictions from 5-fold CV
avg_test_probs = test_probs_sum / 5

# Save Probs
prob_df = pd.DataFrame(avg_test_probs, columns=[f'prob_{i}' for i in range(num_classes_target)])
prob_df['participant_id'] = test_ids.values
prob_df.to_csv('nn_optuna_probs.csv', index=False)
print("✅ Saved 'nn_optuna_probs.csv'")

# Save Submission
final_indices = np.argmax(avg_test_probs, axis=1)
final_labels = target_le.inverse_transform(final_indices)
submission_df = pd.DataFrame({
    'participant_id': test_ids,
    'personality_cluster': final_labels
})
submission_df.to_csv('submission_nn_optuna_20pca.csv', index=False)
print("✅ Saved 'submission_nn_optuna_20pca.csv'")

print("\n" + "="*60)
print("SUMMARY:")
print(f"  Training Set CV F1: {np.mean(final_f1_scores):.4f} ± {np.std(final_f1_scores):.4f}")
print(f"  Evaluation Set F1 (20% held-out): {eval_f1:.4f}")
print(f"  Test Predictions: {len(submission_df)} samples")
print("="*60)
# Out:
# ✅ Saved 'nn_optuna_probs.csv'
# ✅ Saved 'submission_nn_optuna_20pca.csv'
#
# ============================================================
# SUMMARY:
#   Training Set CV F1: 0.6262 ± 0.0890
#   Evaluation Set F1 (20% held-out): 0.4542
#   Test Predictions: 479 samples
# ============================================================
